# %% [markdown]
# <a href="https://colab.research.google.com/github/rozario-lamperouge/NLP/blob/master/FrequentWords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Imporing Nltk**

# %%
import nltk
nltk.download('stopwords')

# %% [markdown]
# ## **Opening url to spacex wiki**

# %%
import urllib.request

url = input("Enter the url :")
response = urllib.request.urlopen(url)
html = response.read()

print(html)
# Out:
# Enter the url :https://en.wikipedia.org/wiki/Chatbot
# ...

# %% [markdown]
# ## **Taking Text from html file**

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html, 'html5lib')
text = soup.get_text(strip="True")
print(text)
# Out:
# Chatbot - Wikipediadocument.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"bc94c8ce-e61d-4446-93a2-a8852d303798","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Chatbot","wgTitle":"Chatbot","wgCurRevisionId":1031462295,"wgRevisionId":1031462295,"wgArticleId":148349,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 errors: missing periodical","All articles with dead external links","Articles with dead external links from February 2021","Articles with permanently dead external links","Articles with short description","Short description is different from Wikidata","Wikipedia articles with GND identifiers",
# ...

# %% [markdown]
# ## **tokenizing**

# %%
tokens = []
for t in text.split():
  tokens.append(t)

print(tokens)
# Out:
# ['Chatbot', '-', 'Wikipediadocument.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"bc94c8ce-e61d-4446-93a2-a8852d303798","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Chatbot","wgTitle":"Chatbot","wgCurRevisionId":1031462295,"wgRevisionId":1031462295,"wgArticleId":148349,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1', 'errors:', 'missing', 'periodical","All', 'articles', 'with', 'dead', 'external', 'links","Articles', 'with', 'dead', 'external', 'links', 'from', 'February', '2021","Articles', 'with', 'permanently', 'dead', 'external', 'links","Articles', 'with', 'short', 'description","Short', 'descri
# ...

# %% [markdown]
# ## **Removing the Stopwords**

# %%
from nltk.corpus import stopwords

sw = stopwords.words('english')

clean_tokens = tokens[:]
print(clean_tokens)
# Out:
# ['Chatbot', '-', 'Wikipediadocument.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"bc94c8ce-e61d-4446-93a2-a8852d303798","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Chatbot","wgTitle":"Chatbot","wgCurRevisionId":1031462295,"wgRevisionId":1031462295,"wgArticleId":148349,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1', 'errors:', 'missing', 'periodical","All', 'articles', 'with', 'dead', 'external', 'links","Articles', 'with', 'dead', 'external', 'links', 'from', 'February', '2021","Articles', 'with', 'permanently', 'dead', 'external', 'links","Articles', 'with', 'short', 'description","Short', 'descri
# ...

# %%
for token in tokens:
  if token in sw:
    clean_tokens.remove(token)

print(clean_tokens)
# Out:
# ['Chatbot', '-', 'Wikipediadocument.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"bc94c8ce-e61d-4446-93a2-a8852d303798","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Chatbot","wgTitle":"Chatbot","wgCurRevisionId":1031462295,"wgRevisionId":1031462295,"wgArticleId":148349,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1', 'errors:', 'missing', 'periodical","All', 'articles', 'dead', 'external', 'links","Articles', 'dead', 'external', 'links', 'February', '2021","Articles', 'permanently', 'dead', 'external', 'links","Articles', 'short', 'description","Short', 'description', 'different', 'Wikidata","Wikiped
# ...

# %% [markdown]
# ## **viewing the amount of stopwords present**

# %%
print(len(tokens) - len(clean_tokens))
print(len(clean_tokens))
# Out:
# 1072
# 3009

# %% [markdown]
# ## **Plotting the 20 most frequent words**

# %%
freq = nltk.FreqDist(clean_tokens)

for key, val in freq.items():
  print(str(key) + ":" + str(val))

freq.plot(20, cumulative=False)
